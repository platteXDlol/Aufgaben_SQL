-- %%
USE FitnessCenter;
SELECT DISTINCT * FROM Orte WHERE Kanton NOT LIKE 'Zürich' OR Kanton NOT LIKE 'Waadt' OR kanton NOT LIKE 'Wallis' ORDER BY Kanton DESC;
-- Out:
-- (8214 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.059
-- ...
